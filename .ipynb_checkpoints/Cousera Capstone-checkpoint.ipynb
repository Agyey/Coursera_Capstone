# %% [markdown]
# # Coursera Capstone Project

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import geopy

def do_geocode(address, attempt=1, max_attempts=5):
    try:
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address)
        return location
    except GeocoderTimedOut:
        if attempt <= max_attempts:
            return do_geocode(address, attempt=attempt+1)
        return None

# %%
neighbourhoods = {}

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
tds = soup.find_all('td', class_=['navbox-list navbox-odd hlist','navbox-list navbox-even hlist'])
trs = soup.find_all('tr')
not_found = []
for tr in trs:
    th = tr.find_all('th')
    td = tr.find_all('td', class_=['navbox-list navbox-odd hlist','navbox-list navbox-even hlist'])
    if td:
        th = th[0]
        td = td[0]
        links = td.find_all('a')
        for link in links:
            print("\n",link.text, link['href'])
            if neighbourhoods and link.text in neighbourhoods["Neighbourhood"]:
                continue
            URL = 'https://en.wikipedia.org' + link['href']
            page = requests.get(URL)
            soup = BeautifulSoup(page.content, 'html.parser')
            spans = soup.find_all('span', class_=['geo-default'])
            if spans:
                text = spans[0].text
                if '/' in text:
                    text = text.split("/")[0]
                lat, long = text.strip().split(" ")
                if "°" in lat:
                    lat, rem = lat.split("°")
                    if "′" in rem:
                        rem, misc = rem.split("′")
                        lat = float(lat) + float(rem)/60
                    else:
                        lat = float(lat)
                if "°" in long:
                    long, rem = long.split("°")
                    if "′" in rem:
                        rem, misc = rem.split("′")
                        long = float(long) + float(rem)/60
                    else:
                        long = float(long)
                print("Longitude : ", -long,"Latitude : ",lat)
                longitude = -long
                latitude = lat
            else:
                address = link.text + ', ' + th.text + ', Toronto'
#                 geolocator = Nominatim(user_agent="foursquare_agent")
#                 location = geolocator.geocode(address)
                location = do_geocode(address)
                if location:
                    latitude = location.latitude
                    longitude = location.longitude
                    print("Longitude : ", longitude,"Latitude : ",latitude)
                else:
                    print("Co-ordinates Not Found ",link.text)
                    not_found.append(link.text)
                    continue   
            if neighbourhoods:
                neighbourhoods["District"].append(th.text)
                neighbourhoods["Neighbourhood"].append(link.text)
                neighbourhoods["Longitude"].append(longitude)
                neighbourhoods["Latitude"].append(latitude)
            else:
                neighbourhoods["District"] = [th.text]
                neighbourhoods["Neighbourhood"] = [link.text]
                neighbourhoods["Longitude"] = [longitude]
                neighbourhoods["Latitude"] = [latitude]
# Out:
#  Alexandra Park /wiki/Alexandra_Park,_Toronto
# Longitude :  -79.4 Latitude :  43.65
#
#  Allenby /wiki/Allenby,_Toronto
# Longitude :  -79.4151072 Latitude :  43.7096995
#
#  The Annex /wiki/The_Annex
# Longitude :  -79.404 Latitude :  43.67
#
#  The Beaches /wiki/The_Beaches
# Longitude :  -79.28333333333333 Latitude :  43.666666666666664
#
#  Bedford Park /wiki/Bedford_Park,_Toronto
# Longitude :  -79.411 Latitude :  43.73
#
#  Bickford Park /wiki/Palmerston-Little_Italy
# Longitude :  -79.41666666666667 Latitude :  43.65
#
#  Bloor West Village /wiki/Bloor_West_Village
# Longitude :  -79.46666666666667 Latitude :  43.65
#
#  Bloor Street Culture Corridor /wiki/Bloor_Street_Culture_Corridor
# Longitude :  -79.3986 Latitude :  43.6678
#
#  Bloordale Village /wiki/Bloordale_Village
# Longitude :  -79.439 Latitude :  43.659
#
#  Bracondale Hill /wiki/Bracondale_Hill
# Longitude :  -79.4244 Latitude :  43.6762
#
#  Brockton Village /wiki/Brockton_Village
# Longitude :  -79.43333333333334 Latitude :  43.65
#
#  Cabbagetown /wiki/Cabbagetown,_Toronto
# Longitude :  -79.3629 Latitude :  43.6664
#
#  Carleton Village /wiki/Carleton_Village
# Longitude :  -79.457 Latitude :  43.672
#
#  Casa Loma /wiki/Casa_Loma_(neighbourhood)
# Longitude :  -79.41 Latitude :  43.67
#
#  Chaplin Estates /wiki/Chaplin_Estates
# Longitude :  -79.4 Latitude :  43.7
#
#  Chinatown /wiki/Chinatown,_Toronto
# Longitude :  -79.398 Latitude :  43.6529
#
#  First Chinatown /wiki/First_Chinatown,_Toronto
# Longitude :  -79.385 Latitude :  43.654
#
#  Christie Pits /wiki/Christie_Pits
# Longitude :  -79.41666666666667 Latitude :  43.65
#
#  Church and Wellesley /wiki/Church_and_Wellesley
# Longitude :  -79.36666666666666 Latitude :  43.65
#
#  CityPlace /wiki/CityPlace,_Toronto
# Longitude :  -79.395179 Latitude :  43.640044
#
#  Corktown /wiki/Corktown,_Toronto
# Longitude :  -79.35 Latitude :  43.65
#
#  Corso Italia /wiki/Corso_Italia_(Toronto)
# Longitude :  -79.445 Latitude :  43.677
#
#  Corso Italia-Davenport /wiki/Corso_Italia-Davenport
# Longitude :  -79.447 Latitude :  43.677
#
#  Davenport /wiki/Davenport,_Toronto
# Longitude :  -79.428 Latitude :  43.673
#
#  Davisville Village /wiki/Davisville_Village
# Longitude :  -79.389 Latitude :  43.701
#
#  Deer Park /wiki/Deer_Park,_Toronto
# Longitude :  -79.38333333333334 Latitude :  43.68333333333333
#
#  Discovery District /wiki/Discovery_District
# Longitude :  -79.388 Latitude :  43.658
#
#  Distillery District /wiki/Distillery_District
# Longitude :  -79.3595401 Latitude :  43.6502947
#
#  Downtown Yonge /wiki/Downtown_Yonge
# Longitude :  -79.36666666666666 Latitude :  43.65
#
#  Dovercourt Park /wiki/Dovercourt_Park
# Longitude :  -79.432 Latitude :  43.665
#
#  Dufferin Grove /wiki/Dufferin_Grove
# Longitude :  -79.428 Latitude :  43.657
#
#  Earlscourt /wiki/Earlscourt
# Longitude :  -79.449 Latitude :  43.678
#
#  East Bayfront /wiki/East_Bayfront
# Longitude :  -79.36459 Latitude :  43.64499
#
#  East Chinatown /wiki/East_Chinatown,_Toronto
# Longitude :  -79.347295 Latitude :  43.666614
#
#  East Danforth /wiki/East_Danforth
# Longitude :  -79.3 Latitude :  43.68333333333333
#
#  East Toronto /wiki/East_Toronto
# Longitude :  -79.2944 Latitude :  43.6808
#
#  Entertainment District /wiki/Toronto_Entertainment_District
# Longitude :  -79.389723 Latitude :  43.6465862
#
#  Fashion District /wiki/Fashion_District,_Toronto
# Longitude :  -79.398 Latitude :  43.645
#
#  Financial District /wiki/Financial_District,_Toronto
# Longitude :  -79.36666666666666 Latitude :  43.63333333333333
#
#  Forest Hill /wiki/Forest_Hill,_Toronto
# Longitude :  -79.41666666666667 Latitude :  43.7
#
#  Garden District /wiki/Garden_District,_Toronto
# Longitude :  -79.3758 Latitude :  43.6585
#
#  Gerrard India Bazaar /wiki/Gerrard_India_Bazaar
# Longitude :  -79.32441 Latitude :  43.67153
#
#  Grange Park /wiki/Grange_Park_(neighbourhood)
# Longitude :  -79.393 Latitude :  43.653
#
#  Greektown /wiki/Greektown,_Toronto
# Longitude :  -79.33333333333333 Latitude :  43.666666666666664
#
#  Harbord Village /wiki/Harbord_Village
# Longitude :  -79.406 Latitude :  43.661
#
#  Harbourfront /wiki/Harbourfront_(Toronto)
# Longitude :  -79.385 Latitude :  43.638
#
#  High Park North /wiki/High_Park_North
# Longitude :  -79.475 Latitude :  43.656
#
#  The Junction /wiki/The_Junction
# Longitude :  -79.45 Latitude :  43.65
#
#  Junction Triangle /wiki/Junction_Triangle
# Longitude :  -79.446 Latitude :  43.659
#
#  Kensington Market /wiki/Kensington_Market
# Longitude :  -79.4 Latitude :  43.65
#
#  Koreatown /wiki/Koreatown,_Toronto
# Longitude :  -79.413005 Latitude :  43.664516
#
#  Lawrence Park /wiki/Lawrence_Park,_Toronto
# Longitude :  -79.388 Latitude :  43.722
#
#  Leslieville /wiki/Leslieville
# Longitude :  -79.332039 Latitude :  43.661927
#
#  Liberty Village /wiki/Liberty_Village
# Longitude :  -79.422 Latitude :  43.637
#
#  Little Italy /wiki/Little_Italy,_Toronto
# Longitude :  -79.413 Latitude :  43.655
#
#  Little Portugal /wiki/Little_Portugal,_Toronto
# Longitude :  -79.43333333333334 Latitude :  43.65
#
#  Little Tibet /wiki/Little_Tibet,_Toronto
# Longitude :  -79.4273119 Latitude :  43.6389445
#
#  Lytton Park /wiki/Lytton_Park
# Longitude :  -79.407833 Latitude :  43.717829
#
#  Midtown /wiki/Midtown,_Toronto
# Longitude :  -79.3991 Latitude :  43.7077
#
#  Moore Park /wiki/Moore_Park,_Toronto
# Longitude :  -79.377 Latitude :  43.691
#
#  Moss Park /wiki/Moss_Park
# Longitude :  -79.367316 Latitude :  43.655709
#
#  Niagara /wiki/Niagara,_Toronto
# Longitude :  -79.408 Latitude :  43.643
#
#  North Toronto /wiki/North_Toronto
# Longitude :  -79.389 Latitude :  43.711
#
#  Norway /wiki/Upper_Beaches
# Longitude :  -79.3 Latitude :  43.666666666666664
#
#  Old Town /wiki/Old_Town,_Toronto
# Longitude :  -79.367912 Latitude :  43.651352
#
#  Palmerston /wiki/Palmerston-Little_Italy
# Longitude :  -79.41666666666667 Latitude :  43.65
#
#  Parkdale /wiki/Parkdale,_Toronto
# Longitude :  -79.436731 Latitude :  43.640454
#
#  Playter Estates /wiki/Playter_Estates
# Longitude :  -79.35 Latitude :  43.666666666666664
#
#  Port Lands /wiki/Port_Lands
# Longitude :  -79.33333333333333 Latitude :  43.63333333333333
#
#  Quayside /wiki/Quayside,_Toronto
# Longitude :  -79.36179 Latitude :  43.646861
#
#  Queen Street West /wiki/Queen_Street_West
# Longitude :  -79.39241 Latitude :  43.649584
#
#  Railway Lands /wiki/Railway_Lands
# Longitude :  -79.38077 Latitude :  43.644662
#
#  Regent Park /wiki/Regent_Park
# Longitude :  -79.35 Latitude :  43.65
#
#  Riverdale /wiki/Riverdale,_Toronto
# Longitude :  -79.33333333333333 Latitude :  43.666666666666664
#
#  Roncesvalles /wiki/Roncesvalles,_Toronto
# Longitude :  -79.449048 Latitude :  43.646231
#
#  Rosedale /wiki/Rosedale,_Toronto
# Longitude :  -79.378 Latitude :  43.679
#
#  Runnymede /wiki/Runnymede,_Toronto
# Longitude :  -79.484 Latitude :  43.6595
#
#  St. James Town /wiki/St._James_Town
# Longitude :  -79.36666666666666 Latitude :  43.666666666666664
#
#  St. Lawrence /wiki/St._Lawrence,_Toronto
# Longitude :  -79.372 Latitude :  43.649
#
#  Seaton Village /wiki/Seaton_Village
# Longitude :  -79.416 Latitude :  43.668
#
#  South Hill /wiki/South_Hill,_Toronto
# Longitude :  -79.4 Latitude :  43.666666666666664
#
#  South Core /wiki/South_Core,_Toronto
# Longitude :  -79.36666666666666 Latitude :  43.63333333333333
#
#  Summerhill /wiki/Summerhill,_Toronto
# Longitude :  -79.39 Latitude :  43.683
#
#  Swansea /wiki/Swansea,_Toronto
# Longitude :  -79.46666666666667 Latitude :  43.63333333333333
#
#  Toronto Islands /wiki/Toronto_Islands
# Longitude :  -79.36666666666666 Latitude :  43.61666666666667
#
#  Trefann Court /wiki/Trefann_Court
# Longitude :  -79.36201 Latitude :  43.656548
#
#  Trinity-Bellwoods /wiki/Trinity-Bellwoods
# Longitude :  -79.40833333333333 Latitude :  43.64666666666667
#
#  Upper Beaches /wiki/Upper_Beaches
# Longitude :  -79.3 Latitude :  43.666666666666664
#
#  Uptown Toronto /wiki/Uptown_Toronto
# Longitude :  -79.4028 Latitude :  43.7264
#
#  Wallace Emerson /wiki/Wallace_Emerson
# Longitude :  -79.441 Latitude :  43.663
#
#  The Ward /wiki/The_Ward,_Toronto
# Longitude :  -79.384 Latitude :  43.656
#
#  West Don Lands /wiki/West_Don_Lands
# Longitude :  -79.353 Latitude :  43.655
#
#  Wychwood Park /wiki/Wychwood_Park
# Longitude :  -79.41933 Latitude :  43.67806
#
#  Yonge-Eglinton /wiki/Yonge-Eglinton
# Longitude :  -79.398271 Latitude :  43.706802
#
#  Yorkville /wiki/Yorkville,_Toronto
# Longitude :  -79.38333333333334 Latitude :  43.666666666666664
#
#  Amesbury /wiki/Amesbury,_Toronto
# Longitude :  -79.48333333333333 Latitude :  43.7
#
#  Armour Heights /wiki/Armour_Heights
# Longitude :  -79.429 Latitude :  43.743
#
#  Bathurst Manor /wiki/Bathurst_Manor
# Longitude :  -79.45 Latitude :  43.75
#
#  Bayview Village /wiki/Bayview_Village
# Longitude :  -79.379 Latitude :  43.777
#
#  Bayview Woods-Steeles /wiki/Bayview_Woods-Steeles
# Longitude :  -79.383 Latitude :  43.797
#
#  Bermondsey /wiki/Bermondsey,_Toronto
# Longitude :  -79.45 Latitude :  43.68333333333333
#
#  Bridle Path /wiki/Bridle_Path,_Toronto
# Longitude :  -79.3733 Latitude :  43.735
#
#  Clanton Park /wiki/Clanton_Park,_Toronto
# Longitude :  -79.45 Latitude :  43.75
#
#  Don Mills /wiki/Don_Mills
# Longitude :  -79.33333333333333 Latitude :  43.733333333333334
#
#  Don Valley Village /wiki/Don_Valley_Village
# Longitude :  -79.35 Latitude :  43.78333333333333
#
#  Downsview /wiki/Downsview
# Longitude :  -79.48333333333333 Latitude :  43.71666666666667
#
#  Flemingdon Park /wiki/Flemingdon_Park
# Longitude :  -79.33333333333333 Latitude :  43.71666666666667
#
#  Glen Park /wiki/Glen_Park,_Toronto
# Longitude :  -79.448 Latitude :  43.708
#
#  Graydon Hall /wiki/Graydon_Hall
# Longitude :  -79.3429 Latitude :  43.763845
#
#  Henry Farm /wiki/Henry_Farm
# Longitude :  -79.352 Latitude :  43.77
#
#  Hillcrest Village /wiki/Hillcrest_Village
# Longitude :  -79.359 Latitude :  43.8
#
#  Hoggs Hollow /wiki/Hoggs_Hollow
# Longitude :  -79.4 Latitude :  43.739
#
#  Humber Summit /wiki/Humber_Summit
# Longitude :  -79.572 Latitude :  43.757
#
#  Humbermede /wiki/Humbermede
# Longitude :  -79.53333333333333 Latitude :  43.733333333333334
#
#  Jane and Finch /wiki/Jane_and_Finch
# Longitude :  -79.51666666666667 Latitude :  43.75
#
#  Lansing /wiki/Lansing,_Toronto
# Longitude :  -79.417 Latitude :  43.757
#
#  Lawrence Heights /wiki/Lawrence_Heights
# Longitude :  -79.45 Latitude :  43.719
#
#  Lawrence Manor /wiki/Lawrence_Manor
# Longitude :  -79.437 Latitude :  43.725
#
#  Maple Leaf /wiki/Maple_Leaf,_Toronto
# Longitude :  -79.489 Latitude :  43.713
#
#  Newtonbrook /wiki/Newtonbrook
# Longitude :  -79.41666666666667 Latitude :  43.78333333333333
#
#  North York City Centre /wiki/North_York_City_Centre
# Longitude :  -79.413 Latitude :  43.769
#
#  Parkway Forest /wiki/Parkway_Forest
# Longitude :  -79.3427 Latitude :  43.7721
#
#  Parkwoods /wiki/Parkwoods
# Longitude :  -79.323 Latitude :  43.751
#
#  Pelmo Park-Humberlea /wiki/Pelmo_Park-Humberlea
# Longitude :  -79.51666666666667 Latitude :  43.71666666666667
#
#  Pleasant View /wiki/Pleasant_View,_Toronto
# Longitude :  -79.335 Latitude :  43.787
#
#  Rustic /wiki/Rustic,_Toronto
# Longitude :  -79.504 Latitude :  43.713
#
#  Teddington Park /wiki/Teddington_Park
# Longitude :  -79.400962 Latitude :  43.734184
#
#  Victoria Village /wiki/Victoria_Village
# Longitude :  -79.3 Latitude :  43.733333333333334
#
#  Westminster-Branson /wiki/Westminster-Branson
# Longitude :  -79.475 Latitude :  43.656
#
#  Willowdale /wiki/Willowdale,_Toronto
# Longitude :  -79.41666666666667 Latitude :  43.78333333333333
#
#  York Mills /wiki/York_Mills
# Longitude :  -79.4 Latitude :  43.733333333333334
#
#  York University Heights /wiki/York_University_Heights
# Longitude :  -79.5 Latitude :  43.762
#
#  Agincourt /wiki/Agincourt,_Toronto
# Longitude :  -79.28333333333333 Latitude :  43.78333333333333
#
#  Armadale /wiki/Armadale,_Ontario
# Longitude :  -79.25 Latitude :  43.833333333333336
#
#  Bendale /wiki/Bendale
# Longitude :  -79.24 Latitude :  43.76
#
#  Birch Cliff /wiki/Birch_Cliff
# Longitude :  -79.26666666666667 Latitude :  43.68333333333333
#
#  Brown's Corners /wiki/Brown%27s_Corners,_Toronto
# Longitude :  -79.23333333333333 Latitude :  43.8
#
#  Clairlea /wiki/Clairlea
# Longitude :  -79.28333333333333 Latitude :  43.7
#
#  Cliffcrest /wiki/Cliffcrest
# Longitude :  -79.231 Latitude :  43.722
#
#  Cliffside /wiki/Cliffside,_Toronto
# Longitude :  -79.23333333333333 Latitude :  43.7
#
#  Dorset Park /wiki/Dorset_Park
# Longitude :  -79.26666666666667 Latitude :  43.75
#
#  Eglinton East /wiki/Eglinton_East
# Longitude :  -79.246 Latitude :  43.74
#
#  Golden Mile /wiki/Golden_Mile,_Toronto
# Longitude :  -79.28333333333333 Latitude :  43.71666666666667
#
#  Guildwood /wiki/Guildwood
# Longitude :  -79.18333333333334 Latitude :  43.733333333333334
#
#  Highland Creek /wiki/Highland_Creek,_Toronto
# Longitude :  -79.16666666666667 Latitude :  43.78333333333333
#
#  Ionview /wiki/Ionview
# Longitude :  -79.26666666666667 Latitude :  43.71666666666667
#
#  L'Amoreaux /wiki/L%27Amoreaux
# Longitude :  -79.31666666666666 Latitude :  43.78333333333333
#
#  Malvern /wiki/Malvern,_Toronto
# Longitude :  -79.21666666666667 Latitude :  43.8
#
#  Maryvale /wiki/Maryvale,_Toronto
# Longitude :  -79.3 Latitude :  43.733333333333334
#
#  Milliken /wiki/Milliken,_Ontario
# Longitude :  -79.3 Latitude :  43.81666666666667
#
#  Morningside /wiki/Morningside,_Toronto
# Longitude :  -79.206 Latitude :  43.787
#
#  Morningside Heights /wiki/Morningside_Heights,_Toronto
# Longitude :  -79.21666666666667 Latitude :  43.81666666666667
#
#  Oakridge /wiki/Oakridge,_Toronto
# Longitude :  -79.26666666666667 Latitude :  43.68333333333333
#
#  Port Union /wiki/Port_Union,_Toronto
# Longitude :  -79.13333333333334 Latitude :  43.766666666666666
#
#  Rouge /wiki/Rouge,_Toronto
# Longitude :  -79.2 Latitude :  43.81666666666667
#
#  Scarborough City Centre /wiki/Scarborough_City_Centre
# Longitude :  -79.25 Latitude :  43.766666666666666
#
#  Scarborough Junction /wiki/Scarborough_Junction
# Longitude :  -79.25 Latitude :  43.71666666666667
#
#  Scarborough Village /wiki/Scarborough_Village
# Longitude :  -79.21666666666667 Latitude :  43.733333333333334
#
#  Steeles /wiki/Steeles,_Toronto
# Longitude :  -79.3145378 Latitude :  43.8161778
#
#  Tam O'Shanter-Sullivan /wiki/Tam_O%27Shanter-Sullivan
# Longitude :  -79.3 Latitude :  43.78333333333333
#
#  West Hill /wiki/West_Hill,_Toronto
# Longitude :  -79.18333333333334 Latitude :  43.766666666666666
#
#  West Rouge /wiki/West_Rouge
# Longitude :  -79.11666666666666 Latitude :  43.78333333333333
#
#  Wexford /wiki/Wexford,_Toronto
# Longitude :  -79.3 Latitude :  43.733333333333334
#
#  Woburn /wiki/Woburn,_Toronto
# Longitude :  -79.21666666666667 Latitude :  43.766666666666666
#
#  Alderwood /wiki/Alderwood,_Toronto
# Longitude :  -79.53333333333333 Latitude :  43.6
#
#  Clairville /wiki/Clairville,_Toronto
# Longitude :  -79.63333333333334 Latitude :  43.75
#
#  Eatonville /wiki/Eatonville,_Toronto
# Longitude :  -79.53333333333333 Latitude :  43.63333333333333
#
#  The Elms /wiki/The_Elms,_Toronto
# Longitude :  -79.55 Latitude :  43.7
#
#  Eringate-Centennial-West Deane /wiki/Eringate-Centennial-West_Deane
# Longitude :  -79.57072 Latitude :  43.661383
#
#  Humber Heights-Westmount /wiki/Humber_Heights-Westmount
# Longitude :  -79.51666666666667 Latitude :  43.68333333333333
#
#  Humber Valley Village /wiki/Humber_Valley_Village
# Longitude :  -79.5 Latitude :  43.666666666666664
#
#  Humberwood /wiki/Humberwood
# Longitude :  -79.5460241478979 Latitude :  43.722525
#
#  Islington-City Centre West /wiki/Islington-City_Centre_West
# Longitude :  -79.51666666666667 Latitude :  43.63333333333333
#
#  Kingsview Village /wiki/Kingsview_Village
# Longitude :  -79.55 Latitude :  43.68333333333333
#
#  The Kingsway /wiki/The_Kingsway
# Longitude :  -79.5 Latitude :  43.63333333333333
#
#  Long Branch /wiki/Long_Branch,_Toronto
# Longitude :  -79.51666666666667 Latitude :  43.583333333333336
#
#  Markland Wood /wiki/Markland_Wood
# Longitude :  -79.56666666666666 Latitude :  43.61666666666667
#
#  Mimico /wiki/Mimico
# Longitude :  -79.48333333333333 Latitude :  43.6
#
#  New Toronto /wiki/New_Toronto
# Longitude :  -79.5 Latitude :  43.6
#
#  Princess Gardens /wiki/Princess_Gardens
# Longitude :  -79.53333333333333 Latitude :  43.666666666666664
#
#  Rexdale /wiki/Rexdale
# Longitude :  -79.56666666666666 Latitude :  43.71666666666667
#
#  Richview /wiki/Richview,_Toronto
# Longitude :  -79.55 Latitude :  43.666666666666664
#
#  The Queensway-Humber Bay /wiki/The_Queensway-Humber_Bay
# Longitude :  -79.48333333333333 Latitude :  43.61666666666667
#
#  Smithfield /wiki/Smithfield,_Toronto
# Longitude :  -79.56666666666666 Latitude :  43.733333333333334
#
#  Thistletown /wiki/Thistletown
# Longitude :  -79.55 Latitude :  43.733333333333334
#
#  Baby Point /wiki/Baby_Point
# Longitude :  -79.48333333333333 Latitude :  43.65
#
#  Fairbank /wiki/Fairbank,_Toronto
# Longitude :  -79.45 Latitude :  43.68333333333333
#
#  Humewood-Cedarvale /wiki/Humewood-Cedarvale
# Longitude :  -79.41666666666667 Latitude :  43.68333333333333
#
#  Lambton /wiki/Lambton,_Toronto
# Longitude :  -79.48333333333333 Latitude :  43.65
#
#  Little Jamaica /wiki/Eglinton_West
# Longitude :  -79.4553 Latitude :  43.69454
#
#  Mount Dennis /wiki/Mount_Dennis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6a7f7b08dbba> in <module>
#      17                 continue
#      18             URL = 'https://en.wikipedia.org' + link['href']
# ---> 19             page = requests.get(URL)
#      20             soup = BeautifulSoup(page.content, 'html.parser')
#      21             spans = soup.find_all('span', class_=['geo-default'])
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~\Anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     492         else:
#     493             while not is_fp_closed(self._fp):
# --> 494                 data = self.read(amt=amt, decode_content=decode_content)
#     495
#     496                 if data:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
neighbourhoodsDF = pd.DataFrame(neighbourhoods)
neighbourhoodsDF.to_csv("neighbourhoods.csv",index=False)
neighbourhoodsDF
